# %%
import tweepy
import csv
import pandas as pd
import sys

# API credentials here
consumer_key = '4BuuaaCBHaacddqudQcRUeFrk'
consumer_secret = 'fhWBU7R1mESOSGsH0zDfpEZJoG0dLBehewtMyykJCHBgA4b9vp'
access_token = '1331165890650517504-3iwJOLhDl0r02K0Ksej74muVvQ9hRa'
access_token_secret = 'gdGOfnoqi3XFbntIY9qgftlEm0GkqZ11S3MJAMHLwMqhM'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True)

# Search word/hashtag value 
HashValue = ""

# search start date value. the search will start from this date to the current date.
StartDate = ""

# getting the search word/hashtag and date range from user
HashValue = input("Enter the hashtag you want the tweets to be downloaded for: ")
StartDate = input("Enter the start date in this format yyyy-mm-dd: ")

# Open/Create a file to append data
csvFile = open(HashValue+'4.csv', 'a')

#Use csv Writer
csvWriter = csv.writer(csvFile)
 # Add a header row to the CSV
for tweet in tweepy.Cursor(api.search,q=HashValue+" -filter:retweets",count=20,lang="en",since=StartDate, tweet_mode='extended').items(10000):
    print (tweet.created_at, tweet.full_text)
    csvWriter.writerow([tweet.created_at, tweet.full_text.encode('utf-8')])

print ("Scraping finished and saved to "+HashValue+".csv")
#sys.exit()
# Out:
# Enter the hashtag you want the tweets to be downloaded for: virtual reality
# Enter the start date in this format yyyy-mm-dd: 2020-08-19
# 2020-12-15 19:34:14 On Thursday 18:00 CEST our Researcher and Community Organiser @Julio_Linares_ will be part of the ART for UBI virtual assembly, discussing Circles and other experimental approaches at making #basicincome a reality. Don't miss it! https://t.co/Tu6lEdSKqn
# 2020-12-15 19:34:11 Online Classrooms Are Now A “Virtual” Reality for Healthcare Providers The following is a guest article by Nanette Koch, VP, Business Development at Atos. During a... - https://t.co/1TMdyrvEhB https://t.co/U5PYMKEsH4
# 2020-12-15 19:33:46 This is a social disorder
# You lost respect for humanity
# Cloaked by a virtual world
# You lost touch with reality
# I fear for the future of mankind
#
# Disconnect me from this world
# Disconnect me from this world
# ...
